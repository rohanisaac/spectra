# %% [markdown]
# Tests of the peak finding and peak fitting features of the module on the XRD data of silicon
#
# Runs 2017/1/9

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import sys
sys.path.append('..')

# %%
from spectra import getxy, find_peaks, fit_data, output_results

# %%
x, y = getxy('../tests/data/xrd.txt')

# %%
pks = find_peaks(x, y, 2)

# %%
plt.plot(x, y)
plt.plot(x[pks], y[pks], 'ro')

# %%
out1 = fit_data(x, y, pks)

# %%
plt.plot(x, y)
plt.plot(x, out1.init_fit)
plt.plot(x, out1.best_fit)

# %%
print(output_results(out1, pandas=True))
# Out:
#                         value             stderr
# parameter
# bg_c0        0.00891394399485  0.000116368058064
# bg_c1      -3.72797894324e-05  4.72518894018e-06
# bg_c2      -1.07063660228e-07  4.20236860615e-08
# p0_x0           16.7594385315   0.00523747645966
# p0_amp        0.0148140189354  0.000669458539953
# p0_fwhm        0.231548636643    0.0151874368766
# p1_x0           28.5621289075   0.00154043404523
# p1_amp        0.0586036613487  0.000575174924228
# p1_fwhm        0.313906362389   0.00441645015864
# p2_x0           47.4024092357    0.0015584731566
# p2_amp        0.0586063406007  0.000568492943773
# p2_fwhm        0.321330171652   0.00446814344071
# p3_x0           56.2174559396    0.0020537882953
# p3_amp        0.0440739590602  0.000573628580004
# p3_fwhm        0.315604288702   0.00589239069509
# p4_x0            69.203576469   0.00809813198513
# p4_amp        0.0110018967413  0.000582707915036
# p4_fwhm        0.305945544329     0.023187497818
# p5_x0             76.40719159    0.0050388604247
# p5_amp        0.0198825026492  0.000518276043727
# p5_fwhm        0.386634875012    0.0144699029747
# p6_x0           88.0620476491   0.00445882138326
# p6_amp        0.0247899898129  0.000469771076248
# p6_fwhm         0.47062746051    0.0130167022211
# p7_x0           94.9489403243   0.00879111111591
# p7_amp        0.0144334917196  0.000409379891585
# p7_fwhm        0.619999727633   0.00640551933729

# %%
# print(output_results(out1, filename='something.txt'))
# Out:
# None

# %%
print(output_results(out1))
# Out:
# [['bg_c0' '0.00891394399485' '0.000116368058064']
#  ['bg_c1' '-3.72797894324e-05' '4.72518894018e-06']
#  ['bg_c2' '-1.07063660228e-07' '4.20236860615e-08']
#  ['p0_x0' '16.7594385315' '0.00523747645966']
#  ['p0_amp' '0.0148140189354' '0.000669458539953']
#  ['p0_fwhm' '0.231548636643' '0.0151874368766']
#  ['p1_x0' '28.5621289075' '0.00154043404523']
#  ['p1_amp' '0.0586036613487' '0.000575174924228']
#  ['p1_fwhm' '0.313906362389' '0.00441645015864']
#  ['p2_x0' '47.4024092357' '0.0015584731566']
#  ['p2_amp' '0.0586063406007' '0.000568492943773']
#  ['p2_fwhm' '0.321330171652' '0.00446814344071']
#  ['p3_x0' '56.2174559396' '0.0020537882953']
#  ['p3_amp' '0.0440739590602' '0.000573628580004']
#  ['p3_fwhm' '0.315604288702' '0.00589239069509']
#  ['p4_x0' '69.203576469' '0.00809813198513']
#  ['p4_amp' '0.0110018967413' '0.000582707915036']
#  ['p4_fwhm' '0.305945544329' '0.023187497818']
#  ['p5_x0' '76.40719159' '0.0050388604247']
#  ['p5_amp' '0.0198825026492' '0.000518276043727']
#  ['p5_fwhm' '0.386634875012' '0.0144699029747']
#  ['p6_x0' '88.0620476491' '0.00445882138326']
#  ['p6_amp' '0.0247899898129' '0.000469771076248']
#  ['p6_fwhm' '0.47062746051' '0.0130167022211']
#  ['p7_x0' '94.9489403243' '0.00879111111591']
#  ['p7_amp' '0.0144334917196' '0.000409379891585']
#  ['p7_fwhm' '0.619999727633' '0.00640551933729']]
